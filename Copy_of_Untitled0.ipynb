# %% [markdown]
# <a href="https://colab.research.google.com/github/uosffff/python-project/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
s=np.array([200,450,300,260,160,750,230])
t=np.sum(s)
m=np.max(s)
print(f"اجمالي مبيعات لاسبوع{t}")
print(f"اعلى مبلغ تم كسبه في الاسبوع{m}")
target=2000
if t > target:
 print("تهنينا لقد وصلت الى الهدف")
else:
 print("انتبه المبيعات منخفظة")
print(s)

# %%
import numpy as np
import matplotlib.pyplot as plt
days=["السبت","الاحد","الاثنين","الثلاثاء","الاربعاء" ]
sales=np.array([200,400,360,260,180])
print(f"toital:{sum(sales)}")
print(f"max:{max(sales)}")
colors=["royalblue","forestgreen","orange","crimson","purple"]

plt.bar(days,sales,color=colors)
plt.xlabel("Days")
plt.ylabel("Sales")
plt.title("Sales Per Day")
plt.show()

# %%
import pandas as pd  # استيراد مكتبة "بانداس" وتسميتها pd (للسهولة)

# إنشاء البيانات (d اختصار لـ Data)
d = {
    'day': ['Sat', 'Sun', 'Mon'],
    'm': [50, 85, None],   # m: العمق بالمتر
    'h': [10, 12, 8]     # h: عدد الساعات
}

# تحويل البيانات لجدول (df اختصار لـ DataFrame)
df = pd.DataFrame(d)
df_cleaned = df.fillna(0)
print("الجدول بعد التنظيف:")
print(df_cleaned)# إضافة عمود السرعة (s اختصار لـ Speed)
df_cleaned['s'] = df_cleaned['m'] / df_cleaned['h']
print(df_cleaned)

# %%
import pandas as pd

# 1. البيانات (d اختصار لـ Data)
d = {
    'id': ['A', 'B', 'C'], # نوع رأس الحفر
    'm': [100, 150, 120],  # الأمتار (meters)
    'h': [5, 10, 4]        # الساعات (hours)
}

# 2. تحويل لجدول (df اختصار لـ DataFrame)
df = pd.DataFrame(d)

# 3. حساب السرعة (r اختصار لـ ROP أو Rate)
df['r'] = df['m'] / df['h']

# 4. استخراج الصف الذي يحتوي على أعلى سرعة باستخدام loc
# idxmax تعطينا رقم الصف، و loc تجلب بياناته
top = df.loc[[df['r'].idxmax()]]
df_all= pd.concat([df,top])

print(df_all)

df_all.to_excel('report.xlsx', index=False)

print("تم إنشاء ملف الإكسيل بنجاح!")

# %%
import pandas as pd

# 1. الجدول
d = {'id': ['A', 'B', 'C'], 'r': [20, 15, 30]}
df = pd.DataFrame(d)

# 2. الفلترة باستخدام query (الاستعلام)
# كأنك تقول لبايثون: "استعلم لي عن الصفوف التي فيها r أكبر من 18"
f = df.query('r > 18')

print(f)

# %%
import pandas as pd

# 1. تجهيز بيانات تحتوي على تكرار لنفس رأس الحفر
d = {
    'id': ['A', 'A', 'B', 'B', 'C', 'C'],
    'm': [100, 150, 120, 130, 110, 140],  # الأمتار
    'h': [5, 7, 6, 6, 4, 8]              # الساعات
}
df = pd.DataFrame(d)

# 2. تجميع البيانات بناءً على النوع (id) وحساب المجموع
# هنا نستخدم groupby لتجميع الحروف المتشابهة ثم sum للمجموع
total_meters = df.groupby('id')[['m','h']].sum()

# 3. حساب متوسط الساعات لكل نوع
avg_hours = df.groupby('id')['h'].mean()

print("--- إجمالي الأمتار لكل رأس حفر ---")
print(total_meters)
print("\n--- متوسط الساعات لكل رأس حفر ---")
print(avg_hours)

# %%
import pandas as pd
import matplotlib.pyplot as plt
d = {"di":['a','a','b','b','c','c'],'m':[150,120,250,300,125,130],'h':[4,6,8,3,6,5]}
df = pd.DataFrame(d)
total_m = df.groupby('di')['m'].sum()
avg_h = df.groupby('di')['h'].mean()

summary = df.groupby('di')['m'].agg(['sum', 'mean', 'max','min'])

ax = total_m.plot(kind='bar', color='skyblue') # أمر الرسم "أعمدة"
ax.bar_label(ax.containers[0], label_type='edge', padding=3)

plt.title('Total Meters per ID') # عنوان الرسم
plt.xlabel('ID')                # اسم المحور الأفقي
plt.ylabel('Total Meters')      # اسم المحور الرأسي
plt.ylim(0, total_m.max() + 100) # زيادة


plt.savefig('drilling_report.png', dpi=300, bbox_inches='tight')
plt.show()                      # أمر إظهار الرسم


print(total_m,'\n')
print(avg_h,'\n')
print(summary)

# %%
import yfinance as yf
from datetime import datetime

# 1. إعدادات العملة
symbol = 'IQD=X'

# 2. جلب البيانات
data = yf.download(symbol, period='1d', progress=False)

# 3. عرض المخرجات بشكل منظم
print("="*35)
print("   تقرير سعر صرف العملة المباشر   ")
print("="*35)

if not data.empty:
    last_price = data['Close'].iloc[-1].item()
    now = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    print(f"🕒 الوقت: {now}")
    print(f"💵 العملة: الدولار مقابل الدينار")
    print(f"💰 السعر الحالي: {last_price:,.2f} IQD")
    print("-" * 35)
    print("الحالة: تم تحديث البيانات بنجاح")
else:
    print("❌ خطأ: لم نتمكن من الوصول للبيانات.")

print("="*35)

# %%
# تحتاج لتثبيت هذه المكتبات أولاً:
# pip install arabic-reshaper python-bidi

import arabic_reshaper
from bidi.algorithm import get_display

def fix_text(text):
    reshaped_text = arabic_reshaper.reshape(text)
    return get_display(reshaped_text)

# عند كتابة العنوان:
plt.title(fix_text("تحليل أداء الحفر"))
plt.xlabel(fix_text("العمق (متر)"))
plt.ylabel(fix_text("سرعة الحفر (متر/ساعة)"))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import arabic_reshaper
from bidi.algorithm import get_display

# دالة إصلاح النص العربي
def fix_text(text):
    reshaped_text = arabic_reshaper.reshape(text)
    return get_display(reshaped_text)

# 1. البيانات
data = {
    'Depth': [1000, 1100, 1200, 1300, 1400, 1500],
    'ROP': [25, 22, 12, 28, 30, 10]
}
df = pd.DataFrame(data)

# 2. إنشاء الرسم
plt.figure(figsize=(9, 6))
plt.plot(df['Depth'], df['ROP'], marker='s', color='green', label=fix_text("معدل الاختراق الفعلي"))

# 3. النصوص والعناوين
plt.title(fix_text("تحليل أداء الحفر (ROP vs Depth)"))
plt.xlabel(fix_text("العمق (أمتار)"))
plt.ylabel(fix_text("سرعة الحفر (متر/ساعة)"))

# 4. خط التنبيه الأحمر
plt.axhline(y=15, color='red', linestyle='--', label=fix_text("الحد الأدنى (15 م/ساعة)"))

# 5. تعديل موقع مفتاح الرسم (Legend)
plt.legend(loc='upper left', shadow=True)

plt.grid(True, linestyle=':', alpha=0.6)

# 6. حفظ الصورة (هذا هو السطر الجديد)
# dpi=300 تجعل جودة الصورة عالية جداً للطباعة
plt.savefig('drilling_report.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import arabic_reshaper
from bidi.algorithm import get_display

# 1. دالة إصلاح النص العربي (لضمان ظهور الحروف متصلة ومن اليمين لليسار)
def fix_text(text):
    reshaped_text = arabic_reshaper.reshape(text)
    return get_display(reshaped_text)

# 2. تحضير البيانات الشاملة (العمق، ROP، WOB، RPM)
data = {
    'Depth': [1000, 1100, 1200, 1300, 1400, 1500],
    'ROP': [25, 22, 12, 28, 30, 10],       # سرعة الحفر (متر/ساعة)
    'WOB': [15, 15, 10, 18, 20, 12],       # الوزن بالطن
    'RPM': [80, 80, 60, 90, 100, 70]       # دورة في الدقيقة
}
df = pd.DataFrame(data)

# 3. إنشاء لوحة رسم تحتوي على رسمين (Subplots)
# الرسم العلوي لـ ROP و WOB، والرسم السفلي لـ RPM
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))

# --- الرسم الأول: ROP مقابل WOB ---
# المحور الأول (الأيسر): ROP باللون الأخضر
line1, = ax1.plot(df['Depth'], df['ROP'], marker='o', color='green', label=fix_text("سرعة الحفر (ROP)"))
ax1.set_xlabel(fix_text("العمق (أمتار)"))
ax1.set_ylabel(fix_text("سرعة الحفر (متر/ساعة)"), color='green')

# المحور الثاني (الأيمن): WOB باللون الأزرق
ax2 = ax1.twinx()
line2, = ax2.plot(df['Depth'], df['WOB'], marker='s', color='blue', linestyle='--', label=fix_text("الوزن (WOB)"))
ax2.set_ylabel(fix_text("الوزن على الريشة (طن)"), color='blue')

ax1.set_title(fix_text("تحليل أداء الحفر: السرعة والوزن مقابل العمق"))
ax1.grid(True, linestyle=':', alpha=0.6)

# دمج مفاتيح الرسم للرسم الأول
lines = [line1, line2]
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper left', shadow=True)

# --- الرسم الثاني: RPM مقابل العمق ---
ax3.plot(df['Depth'], df['RPM'], marker='^', color='purple', label=fix_text("سرعة الدوران (RPM)"))
ax3.set_xlabel(fix_text("العمق (أمتار)"))
ax3.set_ylabel(fix_text("دورة في الدقيقة (RPM)"), color='purple')
ax3.set_title(fix_text("معدل دوران أنابيب الحفر"))
ax3.grid(True, linestyle=':', alpha=0.6)
ax3.legend(loc='upper left', shadow=True)

# 4. حفظ الصورة النهائية وتنسيقها
plt.tight_layout() # لتجنب تداخل الرسوم
plt.savefig('full_drilling_report.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import arabic_reshaper
from bidi.algorithm import get_display

# 1. دالة إصلاح النص العربي
def fix_text(text):
    reshaped_text = arabic_reshaper.reshape(text)
    return get_display(reshaped_text)

# 2. البيانات الشاملة
data = {
    'Depth': [1000, 1100, 1200, 1300, 1400, 1500],
    'ROP': [25, 22, 12, 28, 30, 10],       # سرعة الحفر (متر/ساعة)
    'WOB': [15, 15, 10, 18, 20, 12],       # الوزن بالطن
    'RPM': [80, 81, 60, 90, 100, 70]       # دورة في الدقيقة
}
df = pd.DataFrame(data)

# 3. إنشاء اللوحة الرئيسية
fig, ax1 = plt.subplots(figsize=(12, 7))
fig.subplots_adjust(right=0.75) # توفير مساحة للمحور الثالث على اليمين
# --- المحور الأول (ROP) - يسار ---
line1, = ax1.plot(df['Depth'], df['ROP'], 'g-o', label=fix_text("سرعة الحفر (ROP)"))
ax1.set_xlabel(fix_text("العمق (أمتار)"))
ax1.set_ylabel(fix_text("سرعة الحفر (متر/ساعة)"), color='g')

# --- المحور الثاني (WOB) - يمين أول ---
ax2 = ax1.twinx()
line2, = ax2.plot(df['Depth'], df['WOB'], 'b--s', label=fix_text("الوزن (WOB)"))
ax2.set_ylabel(fix_text("الوزن على الريشة (طن)"), color='b')

# --- المحور الثالث (RPM) - يمين ثاني (خارجي) ---
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60)) # إزاحة المحور للخارج لكي لا يتداخل
line3, = ax3.plot(df['Depth'], df['RPM'], 'r:^', label=fix_text("سرعة الدوران (RPM)"))
ax3.set_ylabel(fix_text("دورة في الدقيقة (RPM)"), color='r')

# 4. التنسيقات والجماليات
plt.title(fix_text("تحليل بارامترات الحفر المتكاملة (ROP, WOB, RPM)"))
ax1.grid(True, linestyle=':', alpha=0.5)

# دمج كل التسميات في مفتاح رسم واحد (Legend)
lines = [line1, line2, line3]
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper left', shadow=True)

# إضافة خط التنبيه لـ ROP
ax1.axhline(y=15, color='black', linestyle='--', alpha=0.7, label=fix_text("حد الكفاءة"))

plt.savefig('all_in_one_drilling.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# !pip install arabic-reshaper python-bidi

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. إدخال البيانات (التي ناقشناها بالأمس)
days = np.array([1, 2, 3, 4, 5, 6, 7])
production = np.array([4200, 4150, 3800, 3200, 2900, 2500, 2100])
pressure = np.array([150, 148, 142, 130, 125, 120, 115])

# 2. إعداد الرسم البياني
fig, ax1 = plt.subplots(figsize=(10, 6))

#معدل الإنتاج (باللون الأخضر - لون النفط)
ax1.set_xlabel('Days')
ax1.set_ylabel('Oil Production (m³/day)', color='green')
ax1.plot(days, production, color='green', marker='o', linewidth=2, label='Production')
ax1.tick_params(axis='y',labelcolor='green')

# إضافة محور آخر لرسم الضغط (باللون الأحمر)
ax2 = ax1.twinx()
ax2.set_ylabel('Wellhead Pressure (Bar)', color='red')
ax2.plot(days, pressure, color='red', marker='s', linestyle='--', label='Pressure')
ax2.tick_params(axis='y', labelcolor='red')

# 3. إضافة اللمسات النهائية للتقرير
plt.title('Well Performance & Pressure Decline Analysis')
plt.grid(True, alpha=0.3)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

# دمجهم في مفتاح واحد يظهر في أفضل مكان تلقائياً
ax1.legend(lines1+lines2,labels1+labels2,loc='upper right',shadow=True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# 1. التنبؤ بالذكاء الاصطناعي
future_days = np.array([8, 9, 10]).reshape(-1, 1)
model = LinearRegression().fit(days.reshape(-1, 1), production)
prediction = model.predict(future_days)

# 2. الرسم البياني
plt.figure(figsize=(10, 5))

# رسم البيانات الحقيقية (بالأخضر)
plt.plot(days, production, 'go-', label='Actual Production')

# رسم التوقعات (باللون الأحمر ومنقط)
plt.plot([7, 8, 9, 10], [production[-1], *prediction], 'ro--', label='AI Prediction')

plt.title('Production Forecast')
plt.xlabel('Days')
plt.ylabel('Production')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# 1. إدخال البيانات الحالية (من صورتك)
days = np.array([1, 2, 3, 4, 5, 6, 7])
production = np.array([4200, 4150, 3800, 3200, 2900, 2500, 2100])
pressure = np.array([150, 148, 142, 130, 125, 120, 115])

# 2. جزء الذكاء الاصطناعي (التنبؤ)
future_days = np.array([8, 9, 10]).reshape(-1, 1)
days_reshaped = days.reshape(-1, 1)

# تدريب النماذج والتنبؤ
model_prod = LinearRegression().fit(days_reshaped, production)
model_press = LinearRegression().fit(days_reshaped, pressure)

prod_pred = model_prod.predict(future_days)
press_pred = model_press.predict(future_days)

# 3. إعداد الرسم البياني المدمج
fig, ax1 = plt.subplots(figsize=(10, 6))

# رسم الإنتاج (الحقيقي + التنبؤ)
ax1.plot(days, production, color='green', marker='o', label='Actual Production')
ax1.plot([7, 8, 9, 10], [production[-1], *prod_pred], color='green', linestyle=':', marker='x', label='AI Pred Production')

# إعداد المحور الثاني للضغط
ax2 = ax1.twinx()
ax2.plot(days, pressure, color='red', marker='s', linestyle='--', label='Actual Pressure')
ax2.plot([7, 8, 9, 10], [pressure[-1], *press_pred], color='red', linestyle=':', marker='x', label='AI Pred Pressure')

# كود إضافة الأرقام للإنتاج (الأخضر)
for x, y in zip([*days.flatten(), *future_days.flatten()], [*production, *prod_pred]):
    ax1.text(x, y + 100, f'{int(y)}', color='green', ha='center', fontsize=8)

# كود إضافة الأرقام للضغط (الأحمر)
for x, y in zip([*days.flatten(), *future_days.flatten()], [*pressure, *press_pred]):
    ax2.text(x, y + 2, f'{int(y)}', color='red', ha='center', fontsize=8)





# التنسيقات النهائية
ax1.set_xlabel('Days')
ax1.set_ylabel('Oil Production (m³/day)', color='green')
ax2.set_ylabel('Wellhead Pressure (Bar)', color='red')
plt.title('Well Performance & AI Prediction Analysis')
plt.grid(True, alpha=0.3)

# دمج مفتاح الرسم (Legend)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')
print(days)
print(future_days)
print(days_reshaped)
print(press_pred)

plt.show()
# حساب دقة النموذج

accuracy = model.score(days, production)
print(f"دقة النموذج هي: {accuracy * 100:.2f}%")

# %%
import sklearn
dir(model_prod)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 1. البيانات (الأيام والإنتاج)
days = np.array([1, 2, 3, 4, 5, 6, 7]).reshape(-1, 1)
production = np.array([4200, 4150, 3800, 3200, 2900, 2500, 2100])

# 2. إنشاء نموذج الذكاء الاصطناعي وتدريبه
model = LinearRegression()
model.fit(days, production)

# 3. التنبؤ باليوم الثامن (Day 8)
next_day = np.array([[8]])
prediction = model.predict(next_day)

print(f"التوقع لإنتاج اليوم الثامن هو: {prediction[0]:.2f}")

# 4. رسم بياني بسيط
plt.scatter(days, production, color='blue', label='Actual Data') # نقاط البيانات الحقيقية
plt.plot(days, model.predict(days), color='red', label='AI Line') # خط التوقع
plt.title('Simple Oil Production Prediction')
plt.xlabel('Days')
plt.ylabel('Production')
plt.legend()
plt.show()
# حساب دقة النموذج
accuracy = model.score(days, production)
print(f"دقة النموذج هي: {accuracy * 100:.2f}%")

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 1. البيانات (الأيام، الإنتاج، الضغط)
days = np.array([1, 2, 3, 4, 5, 6, 7]).reshape(-1, 1)
production = np.array([4200, 4150, 3800, 3200, 2900, 2500, 2100])
pressure = np.array([150, 148, 142, 130, 125, 120, 115])

# 2. بناء وتدريب النماذج
model_prod = LinearRegression().fit(days, production)
model_pres = LinearRegression().fit(days, pressure)

# 3. التنبؤلليوم الثامن
next_day = [[8]]
pred_prod = model_prod.predict(next_day)
pred_pres = model_pres.predict(next_day)

# 4. الرسم البياني المزدوج
fig, ax1 = plt.subplots(figsize=(10, 6))

# رسم الإنتاج (المحور الأيسر - أخضر)
ax1.set_xlabel('Days')
ax1.set_ylabel('Production (m³/day)', color='green')
ax1.scatter(days, production, color='green', label='Actual Production')
ax1.plot(days, model_prod.predict(days), color='green', linestyle='--', label='Prod Trend')
ax1.tick_params(axis='y', labelcolor='green')

# رسم الضغط (المحور الأيمن - أحمر)
ax2 = ax1.twinx()
ax2.set_ylabel('Pressure (Bar)', color='red')
ax2.scatter(days, pressure, color='red', marker='s', label='Actual Pressure')
ax2.plot(days, model_pres.predict(days), color='red', linestyle=':', label='Press Trend')
ax2.tick_params(axis='y', labelcolor='red')

# إضافات نهائية
plt.title('Production & Pressure Prediction')
fig.tight_layout()
plt.grid(True, alpha=0.2)
plt.show()

# طباعة النتائج والدقة
print(f"توقع الإنتاج لليوم 8: {pred_prod[0]:.2f}")
print(f"توقع الضغط لليوم 8: {pred_pres[0]:.2f}")
print(f"دقة نموذج الإنتاج: {model_prod.score(days, production)*100:.2f}%")
print(f"دقة نموذج الضغط: {model_pres.score(days, pressure)*100:.2f}%")

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 1. الأيام
days = np.array([1, 2, 3, 4, 5, 6, 7]).reshape(-1, 1)
last_days=7
d=31
future_days = np.array(range(last_days,last_days+d)).reshape(-1, 1)

# بيانات البئر الأول والثاني
prod1 = np.array([4200, 4100, 3900, 3600, 3300, 3000, 2700])
pres1 = np.array([150, 145, 140, 132, 125, 118, 110])

prod2 = np.array([3000, 2950, 2900, 2850, 2800, 2750, 2700])
pres2 = np.array([130, 129, 128, 127, 126, 125, 124])

# 2. تدريب النماذج والتنبؤ
m_p1 = LinearRegression().fit(days, prod1)
m_r1 = LinearRegression().fit(days, pres1)
m_p2 = LinearRegression().fit(days, prod2)
m_r2 = LinearRegression().fit(days, pres2)


# 3. إعداد الرسم البياني الموحد
fig, ax1 = plt.subplots(figsize=(12, 7))


# رسم البئر 1 (أخضر) والبئر 2 (أزرق)
ax1.plot(days, prod1, 'g-o', label='Well 1 Production')
ax1.plot(days, prod2, 'b-o', label='Well 2 Production')
ax1.plot(future_days, m_p1.predict(future_days), 'g--') # توقع 1
ax1.plot(future_days, m_p2.predict(future_days), 'b--') # توقع 2

# المحور الثاني (الضغط - جهة اليمين)
ax2 = ax1.twinx()
ax2.set_ylabel('Pressure (Bar)')
# رسم البئر 1 (أحمر) والبئر 2 (أرجواني)
ax2.plot(days, pres1, 'r--x', label='Well 1 Pressure')
ax2.plot(days, pres2, 'm--x', label='Well 2 Pressure')
ax2.plot(future_days, m_r1.predict(future_days), 'r:') # توقع 1
ax2.plot(future_days, m_r2.predict(future_days), 'm:') # توقع 2

# دمج التسميات (Legend) في صندوق واحد
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.title('Multi-Well Performance: Production & Pressure Analysis')
plt.grid(True, alpha=0.7)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 1. البيانات الأصلية
days = np.array([1, 2, 3, 4, 5, 6, 7]).reshape(-1, 1)
future_days = np.array([7, 8, 9, 10]).reshape(-1, 1)

prod1 = np.array([4200, 4100, 3900, 3600, 3300, 3000, 2700])
pres1 = np.array([150, 145, 140, 132, 125, 118, 110])
prod2 = np.array([3000, 2950, 2900, 2850, 2800, 2750, 2700])
pres2 = np.array([130, 129, 128, 127, 126, 125, 124])

# 2. تدريب النماذج
m_p1 = LinearRegression().fit(days, prod1)
m_r1 = LinearRegression().fit(days, pres1)
m_p2 = LinearRegression().fit(days, prod2)
m_r2 = LinearRegression().fit(days, pres2)

# استخراج الميل (Slope)
slope = m_p1.coef_[0]

# استخراج الجزء المقطوع (Intercept)
intercept = m_p1.intercept_

print(f"معادلة التنبؤ للبئر الأول هي: y = {slope:.2f}x + {intercept:.2f}")




# --- الجزء الأهم لحل الفجوة ---
# أولاً: نحسب قيم التنبؤ ونخزنها في متغيرات جديدة
pred_prod1 = m_p1.predict(future_days)
pred_prod2 = m_p2.predict(future_days)
pred_pres1 = m_r1.predict(future_days)
pred_pres2 = m_r2.predict(future_days)

# ثانياً: نجبر أول قيمة في التنبؤ أن تكون هي آخر قيمة حقيقية (عند اليوم 7)
pred_prod1[0] = prod1[-1]
pred_prod2[0] = prod2[-1]
pred_pres1[0] = pres1[-1]
pred_pres2[0] = pres2[-1]
# ------------------------------




# 3. الرسم البياني
fig, ax1 = plt.subplots(figsize=(12, 7))

# رسم الإنتاج (استخدام المتغيرات الجديدة pred_prod1 و pred_prod2)
ax1.plot(days, prod1, 'g-o', label='Well 1 Production')
ax1.plot(days, prod2, 'b-o', label='Well 2 Production')
ax1.plot(future_days, pred_prod1, 'g--')
ax1.plot(future_days, pred_prod2, 'b--')
ax1.set_ylabel('Production Rate')
ax1.set_xlabel('Days')





ax2 = ax1.twinx()
ax2.set_ylabel('Pressure (Bar)')
# رسم الضغط (استخدام المتغيرات الجديدة pred_pres1 و pred_pres2)
ax2.plot(days, pres1, 'r--x', label='Well 1 Pressure')
ax2.plot(days, pres2, 'm--x', label='Well 2 Pressure')
ax2.plot(future_days, pred_pres1, 'r.')
ax2.plot(future_days, pred_pres2, 'm.')






# دمج التسميات
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.title('Multi-Well Performance: Production & Pressure Analysis')
plt.grid(True, alpha=0.3)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 1. تجهيز البيانات (100 يوم)
days = np.arange(1, 101).reshape(-1, 1)
# معادلة الإنتاج مع بعض الضجيج العشوائي
production = 5000 * np.exp(-0.01 * days.flatten()) + np.random.normal(0, 50, 100)

# 2. تحويل البيانات للوغاريتم لجعل العلاقة خطية
log_production = np.log(production)

# 3. تدريب النموذج
model = LinearRegression()
model.fit(days, log_production)

# 4. التنبؤ للمستقبل (من يوم 1 إلى 365)
future_days = np.arange(1, 366).reshape(-1, 1)
predicted_log = model.predict(future_days)
predicted_prod = np.exp(predicted_log) # العودة للقيم الطبيعية

# 5. عرض النتيجة ليوم 365
print(f"التنبؤ بالإنتاج بعد سنة: {predicted_prod[-1]:.2f} برميل/يوم")

# 6. رسم الرسم البياني
plt.figure(figsize=(10, 6))
plt.scatter(days, production, color='black', alpha=0.7,s=5, label='Actual Data (100 Days)')
plt.plot(future_days, predicted_prod, color='red', label='Prediction (Up to 365 Days)')
plt.axvline(x=100, color='blue', linestyle='--', label='Today') # خط فاصل

plt.title('Oil Production Forecast (Exponential Decline)')
plt.xlabel('Days')
plt.ylabel('Production (Barrels/Day)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures # أداة جديدة لصنع المنحنيات

# 1. تجهيز البيانات
days = np.arange(1, 101).reshape(-1, 1)
production = 5000 * np.exp(-0.01 * days.flatten()) + np.random.normal(0, 50, 100)

# --- الطريقة الأولى: اللوغاريتم (التي فهمتها سابقاً) ---
log_prod = np.log(production)
model_log = LinearRegression()
model_log.fit(days, log_prod)
pred_log = np.exp(model_log.predict(days))

# --- الطريقة الثانية: المنحنى المباشر (Polynomial) ---
# هنا نجعل البيانات "مرنة" لتقبل الانحناء (درجة 2 تعني قوس بسيط)
poly_features = PolynomialFeatures(degree=2)
days_poly = poly_features.fit_transform(days)
model_poly = LinearRegression()
model_poly.fit(days_poly, production) # نتدرب على الإنتاج مباشرة بدون Log
pred_poly = model_poly.predict(days_poly)

# 2. الرسم البياني للمقارنة
plt.figure(figsize=(10, 6))
plt.scatter(days, production, color='black', s=10, alpha=0.5, label='Actual Data')
plt.plot(days, pred_log, color='red', linewidth=2, label='Model with Log (Exponential)')
plt.plot(days, pred_poly, color='green', linewidth=2, linestyle='--', label='Polynomial Model (Direct Curve)')

plt.title('Log Method vs Polynomial Method')
plt.xlabel('Days')
plt.ylabel('Production')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# 1. تجهيز البيانات (100 يوم فقط)
days = np.arange(1, 101).reshape(-1, 1)
production = 5000 * np.exp(-0.01 * days.flatten()) + np.random.normal(0, 50, 100)

# --- الطريقة الأولى: اللوغاريتم (المنطق الهندسي الآمن) ---
# قمنا بدمج الخطوات وحذف السطر المكرر الذي سبب الخطأ
log_prod = np.log(np.clip(production, 1e-10, None))
model_log = LinearRegression()
model_log.fit(days, log_prod)

# --- الطريقة الثانية: المنحنى المباشر (Polynomial) ---
poly_features = PolynomialFeatures(degree=2)
days_poly = poly_features.fit_transform(days)
model_poly = LinearRegression()
model_poly.fit(days_poly, production)

# 2. التنبؤ للمستقبل البعيد (1000 يوم!)
future_days = np.arange(1, 1001).reshape(-1, 1)

# تنبؤ اللوغاريتم
pred_log_future = np.exp(model_log.predict(future_days))

# تنبؤ المنحنى المباشر
future_days_poly = poly_features.transform(future_days)
pred_poly_future = model_poly.predict(future_days_poly)

# 3. الرسم البياني للمقارنة
plt.figure(figsize=(12, 7))
plt.scatter(days, production, color='black', s=10, alpha=0.5, label='Actual Data (100 Days)')
plt.plot(future_days, pred_log_future, color='red', linewidth=2, label='Log Method (Logical Decline)')
plt.plot(future_days, pred_poly_future, color='green', linewidth=2, linestyle='--', label='Polynomial Method (Dangerous Prediction)')

plt.axvline(x=100, color='blue', linestyle=':', label='Today')
plt.ylim(0, 6000) # لتحديد مجال الرؤية
plt.title('Extrapolation Challenge: Log vs Polynomial')
plt.xlabel('Days')
plt.ylabel('Production (Barrels/Day)')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 1. تجهيز البيانات (100 يوم)
days = np.arange(1, 101).reshape(-1, 1)
pressure = np.linspace(3000, 1500, 100).reshape(-1, 1) # الضغط يبدأ بـ 3000

# معادلة الإنتاج (الواقع)
production = (0.001 * pressure.flatten() * 5000 * np.exp(-0.01 * days.flatten())) + np.random.normal(0, 50, 100)

# 2. تحضير المدخلات واللوغاريتم
X = np.hstack((days, pressure))
log_prod = np.log(np.clip(production, 1e-10, None))

# 3. تدريب النموذج
model = LinearRegression()
model.fit(X, log_prod)

# 4. التنبؤ المستقبلي لـ 365 يوم مع "المعايرة"
future_days = np.arange(1, 366).reshape(-1, 1)
future_pressure = np.linspace(3000, 500, 365).reshape(-1, 1)
X_future = np.hstack((future_days, future_pressure))

# --- خطوة المعايرة لإزالة الفجوة ---
raw_pred = np.exp(model.predict(X_future)) # التوقع الخام
offset = production[0] / raw_pred[0]       # حساب نسبة الفرق عند نقطة البداية
predicted_prod = raw_pred * offset         # التوقع النهائي المنطبق على الواقع

# 5. حساب الدقة (R-squared)
r2_score = model.score(X, log_prod)
print(f"Model Accuracy (R^2 Score): {r2_score:.4f}")

# 6. الرسم البياني النهائي
plt.figure(figsize=(10, 6))
plt.scatter(days, production, color='black', s=8, alpha=0.5, label='Actual Production')
plt.plot(future_days, predicted_prod, color='purple', linewidth=2, label='Calibrated Model (Days + Pressure)')

plt.title(f'Final Calibrated Forecast (R² = {r2_score:.4f})')
plt.xlabel('Days')
plt.ylabel('Barrels/Day')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 1. البيانات التاريخية (100 يوم)
days = np.arange(1, 101).reshape(-1, 1)
pressure = np.linspace(3000, 1500, 100).reshape(-1, 1)
production = (0.001 * pressure.flatten() * 5000 * np.exp(-0.01 * days.flatten())) + np.random.normal(0, 50, 100)

# 2. التدريب
X = np.hstack((days, pressure))
log_prod = np.log(np.clip(production, 1e-10, None))
model = LinearRegression().fit(X, log_prod)

# 3. التنبؤ للمستقبل (من اليوم 101 إلى 365)
future_days = np.arange(101, 366).reshape(-1, 1) # نبدأ من حيث انتهينا
future_pressure = np.linspace(1500, 500, len(future_days)).reshape(-1, 1)
X_future = np.hstack((future_days, future_pressure))

# --- السر هنا: المعايرة عند آخر نقطة حقيقية ---
last_day_real = production[-1] # آخر قيمة حقيقية أنتجها البئر
last_day_pred = np.exp(model.predict(X[-1:])) # توقع النموذج لنفس اليوم الأخير
offset = last_day_real / last_day_pred # معامل التصحيح

predicted_future = np.exp(model.predict(X_future)) * offset

# 4. الرسم البياني
plt.figure(figsize=(10, 6))
# رسم الماضي
plt.scatter(days, production, color='black', s=10, label='Past (Actual)')
# رسم المستقبل (ملتصق تماماً بالماضي)
plt.plot(future_days, predicted_future, color='purple', linewidth=2, label='Future Forecast')

# إضافة نقطة اتصال للتأكيد
plt.scatter(days[-1], production[-1], color='red', s=50, zorder=5, label='Connection Point')

plt.title(f'Perfectly Calibrated Forecast (R² = {model.score(X, log_prod):.4f})')
plt.legend()
plt.show()
